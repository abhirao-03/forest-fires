# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
top_r = np.load('top_r.npy')
top_l = np.load('top_l.npy')

bottom_r = np.load('bottom_r.npy')
bottom_l = np.load('bottom_l.npy')

# %%
top_r = top_r[:752]

# %%
top_r.shape
# Out:
# (752, 765)

# %%
top_l.shape
# Out:
# (752, 743)

# %%
top = np.concatenate([top_l, top_r], axis=1)
plt.imshow(top)
top.shape
# Out:
# (752, 1508)

# %%
bottom_l = bottom_l[:745]

# %%
bottom_r.shape
# Out:
# (745, 750)

# %%
bottom_l.shape
# Out:
# (745, 751)

# %%
bottom = np.concatenate([bottom_l, bottom_r], axis=1)
plt.imshow(bottom)

# %%
bottom.shape
# Out:
# (745, 1501)

# %%
top = top[:, :1501]
plt.imshow(top)

# %%
all = np.concatenate([top, bottom])

# %%
plt.imshow(all)

# %%
np.save('all_densities.npy', all)
